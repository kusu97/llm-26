# %% [markdown]
# ## Install llama.cpp
#
# If you are using macOS, please install it via:
# ```
# brew install llama.cpp
# ```
# Download Qwen3-1.7b model via the following:
# ```
# llama-cli -mu "https://hf-mirror.com/Qwen/Qwen3-1.7B-GGUF/resolve/main/Qwen3-1.7B-Q8_0.gguf" -co auto --jinja -ngl 99 -c 8192 -n 256
# ```
